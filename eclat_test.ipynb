# %%
import numpy as np
import pandas as pd
from my_eclat import Eclat

# %%
# загрузим данные
dataset = pd.read_csv('src/data/Market_Basket_Optimisation.csv', header = None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
model = Eclat(min_support = 30, max_items = 4, min_items = 3)

# %%
model.fit(dataset)

# %%
model.transform()
# Out:
# {'burgers | eggs | chocolate': 41,
#  'burgers | eggs | french fries': 68,
#  'burgers | eggs | ground beef': 30,
#  'burgers | eggs | milk': 40,
#  'burgers | eggs | pancakes': 31,
#  'burgers | eggs | spaghetti': 54,
#  'burgers | french fries | chocolate': 36,
#  'burgers | french fries | spaghetti': 42,
#  'burgers | milk | chocolate': 41,
#  'burgers | milk | french fries': 42,
#  'burgers | milk | ground beef': 31,
#  'burgers | milk | spaghetti': 48,
#  'burgers | spaghetti | chocolate': 48,
#  'burgers | spaghetti | ground beef': 41,
#  'burgers | spaghetti | pancakes': 33,
#  'chocolate | ground beef | herb & pepper': 30,
#  'eggs | chocolate | cake': 32,
#  'eggs | chocolate | ground beef': 49,
#  'eggs | chocolate | pancakes': 42,
#  'eggs | cooking oil | chocolate': 34,
#  'eggs | french fries | cake': 34,
#  'eggs | french fries | chocolate': 63,
#  'eggs | french fries | frozen vegetables': 39,
#  'eggs | french fries | pancakes': 36,
#  'eggs | french fries | spaghetti': 60,
#  'eggs | frozen vegetables | chocolate': 43,
#  'eggs | frozen vegetables | ground beef': 33,
#  'eggs | frozen vegetables | spaghetti': 43,
#  'eggs | ground beef | herb & pepper': 31,
#  'eggs | milk | cake': 31,
#  'eggs | milk | chicken': 31,
#  'eggs | milk | chocolate': 69,
#  'eggs | milk | cooking oil': 30,
#  'eggs | milk | french fries': 54,
#  'eggs | milk | frozen vegetables': 55,
#  'eggs | milk | ground beef': 44,
#  'eggs | milk | pancakes': 35,
#  'eggs | milk | spaghetti': 67,
#  'eggs | spaghetti | cake': 36,
#  'eggs | spaghetti | chicken': 31,
#  'eggs | spaghetti | chocolate': 79,
#  'eggs | spaghetti | cooking oil': 31,
#  'eggs | spaghetti | grated cheese': 32,
#  'eggs | spaghetti | ground beef': 67,
#  'eggs | spaghetti | herb & pepper': 36,
#  'eggs | spaghetti | pancakes': 50,
#  'eggs | turkey | spaghetti': 39,
#  'french fries | chocolate | escalope': 39,
#  'french fries | chocolate | pancakes': 41,
#  'french fries | cookies | chocolate': 30,
#  'french fries | frozen vegetables | chocolate': 42,
#  'french fries | frozen vegetables | spaghetti': 40,
#  'french fries | spaghetti | chocolate': 60,
#  'french fries | spaghetti | ground beef': 42,
#  'french fries | spaghetti | pancakes': 43,
#  'frozen smoothie | frozen vegetables | spaghetti': 31,
#  'frozen smoothie | milk | chocolate': 31,
#  'frozen smoothie | milk | spaghetti': 42,
#  'frozen smoothie | spaghetti | chocolate': 35,
#  'frozen vegetables | chocolate | ground beef': 43,
#  'frozen vegetables | spaghetti | chocolate': 59,
#  'frozen vegetables | spaghetti | ground beef': 65,
#  'frozen vegetables | spaghetti | pancakes': 33,
#  'frozen vegetables | spaghetti | tomatoes': 50,
#  'green tea | burgers | eggs': 45,
#  'green tea | burgers | french fries': 41,
#  'green tea | burgers | spaghetti': 36,
#  'green tea | chocolate | chicken': 30,
#  'green tea | chocolate | pancakes': 32,
#  'green tea | eggs | chocolate': 41,
#  'green tea | eggs | french fries': 53,
#  'green tea | eggs | spaghetti': 43,
#  'green tea | french fries | cake': 33,
#  'green tea | french fries | chocolate': 39,
#  'green tea | french fries | cookies': 35,
#  'green tea | french fries | pancakes': 34,
#  'green tea | french fries | spaghetti': 40,
#  'green tea | frozen vegetables | spaghetti': 32,
#  'green tea | milk | chocolate': 35,
#  'green tea | milk | french fries': 30,
#  'green tea | milk | spaghetti': 39,
#  'green tea | mineral water | cake': 31,
#  'green tea | mineral water | chocolate': 52,
#  'green tea | mineral water | eggs': 52,
#  'green tea | mineral water | french fries': 46,
#  'green tea | mineral water | frozen vegetables': 34,
#  'green tea | mineral water | ground beef': 39,
#  'green tea | mineral water | milk': 43,
#  'green tea | mineral water | olive oil': 32,
#  'green tea | mineral water | pancakes': 43,
#  'green tea | mineral water | spaghetti': 62,
#  'green tea | olive oil | spaghetti': 34,
#  'green tea | spaghetti | chocolate': 53,
#  'green tea | spaghetti | ground beef': 48,
#  'green tea | spaghetti | pancakes': 37,
#  'low fat yogurt | french fries | chocolate': 30,
#  'low fat yogurt | milk | spaghetti': 33,
#  'low fat yogurt | mineral water | chocolate': 43,
#  'low fat yogurt | mineral water | eggs': 46,
#  'low fat yogurt | mineral water | frozen vegetables': 34,
#  'low fat yogurt | mineral water | ground beef': 36,
#  'low fat yogurt | mineral water | milk': 36,
#  'low fat yogurt | mineral water | pancakes': 32,
#  'low fat yogurt | mineral water | spaghetti': 42,
#  'low fat yogurt | spaghetti | ground beef': 30,
#  'milk | chocolate | chicken': 34,
#  'milk | chocolate | ground beef': 46,
#  'milk | chocolate | pancakes': 36,
#  'milk | cooking oil | chocolate': 33,
#  'milk | french fries | chocolate': 55,
#  'milk | french fries | frozen vegetables': 43,
#  'milk | french fries | spaghetti': 48,
#  'milk | frozen vegetables | chocolate': 60,
#  'milk | frozen vegetables | ground beef': 43,
#  'milk | frozen vegetables | spaghetti': 62,
#  'milk | frozen vegetables | tomatoes': 31,
#  'milk | soup | chocolate': 30,
#  'milk | soup | frozen vegetables': 30,
#  'milk | soup | ground beef': 30,
#  'milk | soup | spaghetti': 34,
#  'milk | spaghetti | cake': 31,
#  'milk | spaghetti | chicken': 41,
#  'milk | spaghetti | chocolate': 82,
#  'milk | spaghetti | ground beef': 73,
#  'milk | spaghetti | pancakes': 37,
#  'milk | spaghetti | tomatoes': 44,
#  'milk | whole wheat pasta | spaghetti': 30,
#  'mineral water | burgers | cake': 36,
#  'mineral water | burgers | chocolate': 43,
#  'mineral water | burgers | eggs': 59,
#  'mineral water | burgers | french fries': 39,
#  'mineral water | burgers | frozen vegetables': 37,
#  'mineral water | burgers | ground beef': 40,
#  'mineral water | burgers | milk': 52,
#  'mineral water | burgers | spaghetti': 49,
#  'mineral water | chicken | pancakes': 36,
#  'mineral water | chocolate | cake': 42,
#  'mineral water | chocolate | chicken': 57,
#  'mineral water | chocolate | escalope': 42,
#  'mineral water | chocolate | fresh bread': 30,
#  'mineral water | chocolate | grated cheese': 30,
#  'mineral water | chocolate | ground beef': 82,
#  'mineral water | chocolate | herb & pepper': 30,
#  'mineral water | chocolate | pancakes': 70,
#  'mineral water | chocolate | tomatoes': 43,
#  'mineral water | cooking oil | chocolate': 43,
#  'mineral water | cooking oil | pancakes': 35,
#  'mineral water | eggs | cake': 54,
#  'mineral water | eggs | chicken': 39,
#  'mineral water | eggs | chocolate': 101,
#  'mineral water | eggs | chocolate | ground beef': 30,
#  'mineral water | eggs | cooking oil': 48,
#  'mineral water | eggs | french fries': 52,
#  'mineral water | eggs | frozen vegetables': 68,
#  'mineral water | eggs | grated cheese': 33,
#  'mineral water | eggs | ground beef': 76,
#  'mineral water | eggs | herb & pepper': 40,
#  'mineral water | eggs | milk': 98,
#  'mineral water | eggs | milk | chocolate': 31,
#  'mineral water | eggs | milk | spaghetti': 33,
#  'mineral water | eggs | pancakes': 59,
#  'mineral water | eggs | soup': 37,
#  'mineral water | eggs | spaghetti': 107,
#  'mineral water | eggs | spaghetti | chocolate': 34,
#  'mineral water | eggs | tomatoes': 38,
#  'mineral water | eggs | turkey': 42,
#  'mineral water | french fries | cake': 48,
#  'mineral water | french fries | chicken': 32,
#  'mineral water | french fries | chocolate': 64,
#  'mineral water | french fries | frozen vegetables': 46,
#  'mineral water | french fries | ground beef': 40,
#  'mineral water | french fries | pancakes': 49,
#  'mineral water | french fries | spaghetti': 76,
#  'mineral water | frozen smoothie | chocolate': 38,
#  'mineral water | frozen smoothie | eggs': 31,
#  'mineral water | frozen smoothie | milk': 46,
#  'mineral water | frozen smoothie | spaghetti': 51,
#  'mineral water | frozen vegetables | cake': 36,
#  'mineral water | frozen vegetables | chocolate': 73,
#  'mineral water | frozen vegetables | ground beef': 69,
#  'mineral water | frozen vegetables | pancakes': 46,
#  'mineral water | frozen vegetables | spaghetti': 90,
#  'mineral water | frozen vegetables | spaghetti | chocolate': 31,
#  'mineral water | frozen vegetables | spaghetti | ground beef': 33,
#  'mineral water | frozen vegetables | tomatoes': 44,
#  'mineral water | grated cheese | ground beef': 38,
#  'mineral water | ground beef | herb & pepper': 50,
#  'mineral water | milk | cake': 48,
#  'mineral water | milk | chicken': 50,
#  'mineral water | milk | chocolate': 105,
#  'mineral water | milk | cooking oil': 35,
#  'mineral water | milk | escalope': 30,
#  'mineral water | milk | french fries': 62,
#  'mineral water | milk | fresh bread': 30,
#  'mineral water | milk | frozen vegetables': 83,
#  'mineral water | milk | frozen vegetables | chocolate': 30,
#  'mineral water | milk | frozen vegetables | spaghetti': 34,
#  'mineral water | milk | ground beef': 83,
#  'mineral water | milk | herb & pepper': 31,
#  'mineral water | milk | pancakes': 59,
#  'mineral water | milk | soup': 64,
#  'mineral water | milk | spaghetti': 118,
#  'mineral water | milk | spaghetti | chocolate': 37,
#  'mineral water | milk | spaghetti | ground beef': 33,
#  'mineral water | milk | tomatoes': 49,
#  'mineral water | milk | whole wheat rice': 38,
#  'mineral water | olive oil | chocolate': 62,
#  'mineral water | olive oil | eggs': 44,
#  'mineral water | olive oil | french fries': 30,
#  'mineral water | olive oil | frozen vegetables': 49,
#  'mineral water | olive oil | ground beef': 50,
#  'mineral water | olive oil | milk': 64,
#  'mineral water | olive oil | pancakes': 35,
#  'mineral water | olive oil | soup': 39,
#  'mineral water | olive oil | spaghetti': 77,
#  'mineral water | olive oil | tomatoes': 31,
#  'mineral water | pancakes | cake': 31,
#  'mineral water | pancakes | ground beef': 56,
#  'mineral water | salmon | chocolate': 34,
#  'mineral water | salmon | milk': 33,
#  'mineral water | salmon | spaghetti': 51,
#  'mineral water | soup | chocolate': 42,
#  'mineral water | soup | frozen vegetables': 38,
#  'mineral water | soup | ground beef': 38,
#  'mineral water | soup | pancakes': 32,
#  'mineral water | soup | spaghetti': 56,
#  'mineral water | spaghetti | cake': 53,
#  'mineral water | spaghetti | chicken': 52,
#  'mineral water | spaghetti | chocolate': 119,
#  'mineral water | spaghetti | chocolate | ground beef': 30,
#  'mineral water | spaghetti | cooking oil': 57,
#  'mineral water | spaghetti | escalope': 36,
#  'mineral water | spaghetti | grated cheese': 47,
#  'mineral water | spaghetti | ground beef': 128,
#  'mineral water | spaghetti | herb & pepper': 45,
#  'mineral water | spaghetti | pancakes': 86,
#  'mineral water | spaghetti | red wine': 30,
#  'mineral water | spaghetti | tomatoes': 70,
#  'mineral water | tomatoes | ground beef': 41,
#  'mineral water | tomatoes | pancakes': 35,
#  'mineral water | turkey | chocolate': 31,
#  'mineral water | turkey | frozen vegetables': 33,
#  'mineral water | turkey | milk': 46,
#  'mineral water | turkey | spaghetti': 48,
#  'mineral water | whole wheat rice | frozen vegetables': 33,
#  'mineral water | whole wheat rice | pancakes': 31,
#  'mineral water | whole wheat rice | spaghetti': 47,
#  'olive oil | eggs | chocolate': 30,
#  'olive oil | eggs | spaghetti': 38,
#  'olive oil | frozen vegetables | chocolate': 30,
#  'olive oil | frozen vegetables | spaghetti': 43,
#  'olive oil | milk | chocolate': 39,
#  'olive oil | milk | frozen vegetables': 36,
#  'olive oil | milk | ground beef': 37,
#  'olive oil | milk | spaghetti': 54,
#  'olive oil | spaghetti | chocolate': 53,
#  'olive oil | spaghetti | ground beef': 46,
#  'olive oil | spaghetti | pancakes': 38,
#  'olive oil | spaghetti | tomatoes': 33,
#  'salmon | spaghetti | chocolate': 30,
#  'shrimp | eggs | milk': 32,
#  'shrimp | eggs | spaghetti': 30,
#  'shrimp | frozen vegetables | chocolate': 40,
#  'shrimp | frozen vegetables | spaghetti': 45,
#  'shrimp | frozen vegetables | tomatoes': 30,
#  'shrimp | milk | chocolate': 41,
#  'shrimp | milk | frozen vegetables': 35,
#  'shrimp | milk | spaghetti': 37,
#  'shrimp | mineral water | chocolate': 57,
#  'shrimp | mineral water | eggs': 39,
#  'shrimp | mineral water | frozen vegetables': 54,
#  'shrimp | mineral water | ground beef': 38,
#  'shrimp | mineral water | milk': 59,
#  'shrimp | mineral water | olive oil': 34,
#  'shrimp | mineral water | pancakes': 34,
#  'shrimp | mineral water | spaghetti': 64,
#  'shrimp | spaghetti | chocolate': 48,
#  'shrimp | spaghetti | ground beef': 45,
#  'shrimp | spaghetti | tomatoes': 30,
#  'spaghetti | chicken | ground beef': 36,
#  'spaghetti | chocolate | cake': 39,
#  'spaghetti | chocolate | chicken': 32,
#  'spaghetti | chocolate | escalope': 33,
#  'spaghetti | chocolate | ground beef': 69,
#  'spaghetti | chocolate | pancakes': 51,
#  'spaghetti | chocolate | tomatoes': 37,
#  'spaghetti | cooking oil | chocolate': 33,
#  'spaghetti | cooking oil | ground beef': 36,
#  'spaghetti | grated cheese | ground beef': 40,
#  'spaghetti | ground beef | herb & pepper': 48,
#  'spaghetti | pancakes | cake': 31,
#  'spaghetti | pancakes | ground beef': 48,
#  'spaghetti | tomatoes | ground beef': 42,
#  'turkey | milk | spaghetti': 36,
#  'whole wheat rice | spaghetti | chocolate': 31}
