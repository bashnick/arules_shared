# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sys  import argv, stderr, maxsize

# %%
# загрузим данные
dataset = pd.read_csv('src/data/Market_Basket_Optimisation.csv', header = None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
#global variables
item_lst = list(item_dict.keys())
item_len = len(item_lst)
final_dict = dict()

# %%
def read_data(dataset)
    item_dict = dict()
    for index, row in dataset.iterrows():
        row_wo_na = row.dropna().unique()
        for item in row_wo_na:
            item = item.strip()
            if item in item_dict:
                item_dict[item][0] += 1
            else:
                item_dict.setdefault(item, []).append(1)
            item_dict[item].append(index) #later a more sofisticated data structure can be used to search more efficient
    return item_dict

# %%
def recur_eclat(item_name, tids_array, minsupp, k_start):
    if tids_array[0] >= minsupp:
        for k in range(k_start+1, item_len):
            if item_dict[item_lst[k]][0] >= minsupp:
                new_item = item_name + " " + item_lst[k]
                new_tids = np.intersect1d(tids_array[1:], item_dict[item_lst[k]][1:])
                new_tids_size = new_tids.size
                np.insert(new_tids, 0, new_tids_size)
                if new_tids_size >= minsupp:
                    final_dict.update({new_item: new_tids})
                    print (new_item, new_tids_size)
                    recur_eclat(new_item, new_tids, minsupp, k)
    return final_dict

# %%
def fit(dataset):
    
    i = 0
    for w in item_lst:
        recur_eclat(w, item_dict[w], 10, i)
        i+=1
# Out:
# Wall time: 0 ns
# shrimp almonds 17
# shrimp avocado 23
# shrimp vegetables mix 20
# shrimp cottage cheese 20
# shrimp energy drink 21
# shrimp tomato juice 27
# shrimp low fat yogurt 47
# shrimp green tea 86
# shrimp honey 33
# shrimp mineral water 177
# shrimp salmon 35
# shrimp frozen smoothie 55
# shrimp olive oil 61
# shrimp burgers 66
# shrimp burgers eggs 16
# shrimp burgers milk 22
# shrimp burgers whole wheat rice 12
# shrimp burgers french fries 19
# shrimp burgers frozen vegetables 11
# shrimp burgers spaghetti 21
# shrimp burgers spaghetti chocolate 10
# shrimp burgers chocolate 23
# shrimp burgers tomatoes 11
# shrimp burgers pasta 10
# shrimp burgers pancakes 12
# shrimp burgers ground beef 10
# shrimp meatballs 20
# shrimp eggs 106
# shrimp eggs turkey 14
# shrimp eggs milk 32
# shrimp eggs milk chocolate 11
# shrimp eggs french fries 21
# shrimp eggs frozen vegetables 28
# shrimp eggs spaghetti 30
# shrimp eggs spaghetti chocolate 11
# shrimp eggs chocolate 28
# ...
