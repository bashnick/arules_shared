# %%
import numpy as np
import pandas as pd
from my_eclat import Eclat

# %%
# загрузим данные
dataset = pd.read_csv('src/data/Market_Basket_Optimisation.csv', header = None)

# %%
dataset.shape[0]
# Out:
# 7501

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
model = Eclat(min_support = 0.3, max_items = 2, min_items = 2)

# %%
# %%time
model.fit(dataset)
# Out:
# Wall time: 3.61 s

# %%
d = model.transform()

# %%
d
# Out:
# {'shrimp | almonds': 17,
#  'shrimp | avocado': 23,
#  'shrimp | vegetables mix': 20,
#  'shrimp | green grapes': 8,
#  'shrimp | whole weat flour': 7,
#  'shrimp | yams': 8,
#  'shrimp | cottage cheese': 20,
#  'shrimp | energy drink': 21,
#  'shrimp | tomato juice': 27,
#  'shrimp | low fat yogurt': 47,
#  'shrimp | green tea': 86,
#  'shrimp | honey': 33,
#  'shrimp | salad': 6,
#  'shrimp | mineral water': 177,
#  'shrimp | salmon': 35,
#  'shrimp | antioxydant juice': 5,
#  'shrimp | frozen smoothie': 55,
#  'shrimp | spinach': 5,
#  'shrimp | olive oil': 61,
#  'shrimp | burgers': 66,
#  'shrimp | meatballs': 20,
#  'shrimp | eggs': 106,
#  'shrimp | chutney': 3,
#  'shrimp | turkey': 48,
#  'shrimp | milk': 132,
#  'shrimp | energy bar': 11,
#  'shrimp | whole wheat rice': 44,
#  'shrimp | whole wheat pasta': 26,
#  'shrimp | french fries': 75,
#  'shrimp | soup': 42,
#  'shrimp | light cream': 19,
#  'shrimp | shallot': 1,
#  'shrimp | frozen vegetables': 125,
# ...
