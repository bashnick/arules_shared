# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyfim
from sys  import argv, stderr, maxsize

# %%
# загрузим данные
dataset = pd.read_csv('src/data/Market_Basket_Optimisation.csv', header = None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
min_supp = 200

# %%
item_dict = dict()

# %%
for index, row in dataset.iterrows():
    row_wo_na = row.dropna().unique()
    for item in row_wo_na:
        item = item.strip()
        if item in item_dict:
            item_dict[item][0] += 1
        else:
            item_dict.setdefault(item, []).append(1)
        item_dict[item].append(index) #later a more sofisticated data structure can be used to search more efficient

# %%
item_lst = list(item_dict.keys())
item_len = len(item_lst)

# %%
def recur_eclat(new_item, new_tids, minsupp, k_start):
    if next_item[keys_lst[k_min]][0] >= minsupp:
        for k in range(k_start, item_len):
            if item_dict[item_lst[k]][0] >= minsupp:
                new_item = keys_lst[k_min] + " " + item_lst[k]
                new_tids = np.intersect1d(recur_dict[keys_lst[k_min]][1:], item_dict[item_lst[k]][1:])
                new_tids_size = new_tids.size
                new_value = [new_tids_size].append(new_tids)
                print (new_item)
                if new_tids_size >= minsupp:
                    final_dict.update({new_item: new_value})
                    recur_eclat(new_item, new_tids, minsupp, k)

# %%
final_dict = dict()

# %%
recur_eclat(item_dict, minsupp = min_supp)
# Out:
# 0
# shrimp avocado
# shrimp cottage cheese
# shrimp energy drink
# shrimp tomato juice
# shrimp low fat yogurt
# shrimp green tea
# shrimp honey
# shrimp mineral water
# shrimp salmon
# shrimp frozen smoothie
# shrimp olive oil
# shrimp burgers
# shrimp eggs
# shrimp turkey
# shrimp milk
# shrimp energy bar
# shrimp whole wheat rice
# shrimp whole wheat pasta
# shrimp french fries
# shrimp soup
# shrimp frozen vegetables
# shrimp spaghetti
# shrimp cookies
# shrimp cooking oil
# shrimp champagne
# shrimp chocolate
# shrimp chicken
# shrimp tomatoes
# shrimp red wine
# shrimp pancakes
# shrimp grated cheese
# shrimp fresh bread
# shrimp ground beef
# shrimp escalope
# shrimp herb & pepper
# shrimp cake
# shrimp hot dogs
# shrimp brownies
# shrimp light mayo
# shrimp yogurt cake
# shrimp butter
# 1
# 2
# avocado cottage cheese
# avocado energy drink
# avocado tomato juice
# avocado low fat yogurt
# avocado green tea
# avocado honey
# avocado mineral water
# avocado salmon
# ...
